# %% [markdown]
# ### Introducción
#
# ### Esta es la primera clase de Python y estamos conociendo la sintaxis básica de un Jupyter Notebook
#
# - Paso 1: Crear un archivo con extensión **ipynb**
# - Paso 2: Podemos crear celdas de Markdown y de Código pulsando en los botones correspondientes
# - Paso 3: Podemos crear documentación de nuestro código:
#
# ```html
# <h1>Hola</h1>
# <p>
#   Esto es un bloque de código como el que podemos ver en el temario de la
#   plataforma
# </p>
# ```

# %%
variable=10*10
print(variable)
# Out:
# 100

# %%
saludo = "Hola, estamos en Python"
print(saludo)
# Out:
# Hola, estamos en Python
