# %% [markdown]
# ## Variables

# %%
# nombre de variable + operador de asignación = + el valor de la variable
nombre = "Jose"
edad = 32
altura = 1.76

print(nombre)
# Out:
# Jose

# %% [markdown]
# ## Tipos de Datos

# %%
# NUMEROS
entero = 87
numero_float = 87.5
numero_negativo = -20.5
numero_complejo = 2 + 4j

print(numero_complejo.real)
print(numero_complejo.imag)

# STRING
string1 = 'Hola'
string2 = "Hola"
string3 = "El gato dijo: 'Miau'"

fstrings = f"Mi nombre es {nombre}, tengo {edad} años, y mido {altura} metros."
print(fstrings)

plantilla = f"""
Buenos dias,

Mi nombre es {nombre}.

Tengo {edad} años.

Y quiero postular al equipo de baloncesto porque mido {altura} metros de altura.

Un cordial saludo.
"""

print(plantilla)

# NONE
ausencia_de_valor = None
print("Asuencia de valor es de tipo None?", ausencia_de_valor is None)

# BOOLEANS
verdadero = True
falso = False
# Out:
# 2.0
# 4.0
# Mi nombre es Jose, tengo 32 años, y mido 1.76 metros.
#
# Buenos dias,
#
# Mi nombre es Jose.
#
# Tengo 32 años.
#
# Y quiero postular al equipo de baloncesto porque mido 1.76 metros de altura.
#
# Un cordial saludo.
#
# Asuencia de valor es de tipo None? True
